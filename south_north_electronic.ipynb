# %% [markdown]
# <a href="https://colab.research.google.com/github/victoria2012/test_visualization/blob/master/south_north_electronic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('./남북한발전전력량.xlsx')
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 1       NaN     수력    64    51    49    60  ...    78    77    84    78    58    66
# 2       NaN     화력   484   573   696   803  ...  3343  3430  3581  3427  3402  3523
# 3       NaN    원자력   529   563   565   581  ...  1547  1503  1388  1564  1648  1620
# 4       NaN    신재생     -     -     -     -  ...     -    86   118   151   173   195
# 5        북한     합계   277   263   247   221  ...   211   215   221   216   190   239
# 6       NaN     수력   156   150   142   133  ...   132   135   139   130   100   128
# 7       NaN     화력   121   113   105    88  ...    79    80    82    86    90   111
# 8       NaN    원자력     -     -     -     -  ...     -     -     -     -     -     -
#
# [9 rows x 29 columns]

# %%
df_water = df.iloc[[1,6],12:]
df_water
# Out:
#   2000 2001 2002 2003 2004 2005 2006  ... 2010 2011 2012 2013 2014 2015 2016
# 1   56   42   53   69   59   52   52  ...   65   78   77   84   78   58   66
# 6  102  106  106  117  125  131  126  ...  134  132  135  139  130  100  128
#
# [2 rows x 17 columns]

# %%
df_water.index = ['South','North']                     
df_water
# Out:
#       2000 2001 2002 2003 2004 2005 2006  ... 2010 2011 2012 2013 2014 2015 2016
# South   56   42   53   69   59   52   52  ...   65   78   77   84   78   58   66
# North  102  106  106  117  125  131  126  ...  134  132  135  139  130  100  128
#
# [2 rows x 17 columns]

# %%
df_water_tran = df_ns.transpose()
df_water_tran
# Out:
#      South North
# 2000    56   102
# 2001    42   106
# 2002    53   106
# 2003    69   117
# 2004    59   125
# 2005    52   131
# 2006    52   126
# 2007    50   133
# 2008    56   141
# 2009    56   125
# 2010    65   134
# 2011    78   132
# 2012    77   135
# 2013    84   139
# 2014    78   130
# 2015    58   100
# 2016    66   128

# %%
type(df_water_tran)
# Out:
# pandas.core.frame.DataFrame

# %%
df_water_tran.plot(kind='line')

# %%
df_water_tran.plot(kind='bar')

# %%
df_fire = df.loc[[2,7],'1990':'2014']
df_fire
# Out:
#   1990 1991 1992 1993  1994  1995  ...  2009  2010  2011  2012  2013  2014
# 2  484  573  696  803  1022  1122  ...  2802  3196  3343  3430  3581  3427
# 7  121  113  105   88    93    88  ...   110   103    79    80    82    86
#
# [2 rows x 25 columns]

# %%
df_fire.index = ['South','North']
df_fire
# Out:
#       1990 1991 1992 1993  1994  1995  ...  2009  2010  2011  2012  2013  2014
# South  484  573  696  803  1022  1122  ...  2802  3196  3343  3430  3581  3427
# North  121  113  105   88    93    88  ...   110   103    79    80    82    86
#
# [2 rows x 25 columns]

# %%
df_fire_tran = df_fire.transpose()
df_fire_tran
# Out:
#      South North
# 1990   484   121
# 1991   573   113
# 1992   696   105
# 1993   803    88
# 1994  1022    93
# 1995  1122    88
# 1996  1264    88
# 1997  1420    86
# 1998  1195    68
# 1999  1302    83
# 2000  1518    92
# 2001  1689    96
# 2002  1821    84
# 2003  1859    79
# 2004  2056    81
# 2005  2127    84
# 2006  2272    99
# 2007  2551   103
# 2008  2658   114
# 2009  2802   110
# 2010  3196   103
# 2011  3343    79
# 2012  3430    80
# 2013  3581    82
# 2014  3427    86

# %%
df_fire_tran.plot()

# %%
df_fire_tran.plot(kind='bar')

# %%
df_atomic = df.iloc[[3,8],12:-1]
df_atomic
# Out:
#    2000  2001  2002  2003  2004  2005  ...  2010  2011  2012  2013  2014  2015
# 3  1090  1121  1191  1297  1307  1468  ...  1486  1547  1503  1388  1564  1648
# 8     -     -     -     -     -     -  ...     -     -     -     -     -     -
#
# [2 rows x 16 columns]

# %%
df_atomic_tran = df_atomic.transpose()
df_atomic_tran
# Out:
#          3  8
# 2000  1090  -
# 2001  1121  -
# 2002  1191  -
# 2003  1297  -
# 2004  1307  -
# 2005  1468  -
# 2006  1487  -
# 2007  1429  -
# 2008  1510  -
# 2009  1478  -
# 2010  1486  -
# 2011  1547  -
# 2012  1503  -
# 2013  1388  -
# 2014  1564  -
# 2015  1648  -

# %%
df_atomic_tran.plot(kind='line')
